# %%
import skimage 
import matplotlib.pyplot as plt

# %%
I = skimage.data.camera()

# %%
print(I)
# Out:
# [[200 200 200 ... 189 190 190]
#  [200 199 199 ... 190 190 190]
#  [199 199 199 ... 190 190 190]
#  ...
#  [ 25  25  27 ... 139 122 147]
#  [ 25  25  26 ... 158 141 168]
#  [ 25  25  27 ... 151 152 149]]

# %%
I.shape
# Out:
# (512, 512)

# %%
plt.imshow(I)

# %%
plt.imshow(I, 'gray')
plt.show()

# %%
cat = skimage.data.chelsea()

# %%
print(cat.shape)
# Out:
# (300, 451, 3)

# %%
print(cat.dtype)
# Out:
# uint8

# %%
plt.imshow(cat)
plt.show()

# %%
for c in range(3):
    plt.imshow(cat[:,:,c], 'gray')
    plt.show()

# %%
Pour ajouter une image depuis le local

I = skimage.io.imread('test.jpg')

# %%
print(cat.max())
print(cat.min())
# Out:
# 231
# 0
